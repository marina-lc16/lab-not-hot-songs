# %% [markdown]
# # Lab | Not hot songs

# %% [markdown]
# **Prepare a new dataset of not_hot_songs. This dataset can contain songs of your choice, others collected from the web or any other combination**

# %%
# 1. import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# 2. Explore the dataset

songs_file = pd.read_csv('Spotify_Top_Hit_Playlist_2010_2022.csv')
songs_file.head()


# Dataset taken from: https://www.kaggle.com/datasets/josephinelsy/spotify-top-hit-playlist-2010-2022
# Out:
#                                         playlist_url  year  \
# 0  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 1  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 2  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 3  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 4  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
#
#                  track_id            track_name  track_popularity  \
# 0  3AJwUDP919kvQ9QcozQPxg                Yellow                91
# 1  2m1hi0nfMR9vdGC8UcrnwU  All The Small Things                84
# 2  3y4LxiYMgDl4RethdzpmNe               Breathe                69
# 3  60a0Rd6pjrkxjPbaKzXjfq            In the End                88
# 4  62bOmKYxYg7dhrC6gH9vFn           Bye Bye Bye                74
#
#                            album               artist_id  artist_name  \
# 0                     Parachutes  4gzpq5DPGxSnKTe4SA8HAU     Coldplay
# ...

# %%
# Create a new DataFrame with columns "track_name" as Title an "artist_name" as Artist

not_hot_song = pd.DataFrame().assign(Titles=songs_file['track_name'], Artist=songs_file['artist_name'])
not_hot_song.head()
# Out:
#                  Titles       Artist
# 0                Yellow     Coldplay
# 1  All The Small Things    blink-182
# 2               Breathe   Faith Hill
# 3            In the End  Linkin Park
# 4           Bye Bye Bye       *NSYNC

# %%
#Get DF ino

not_hot_song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2300 entries, 0 to 2299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Titles  2300 non-null   object
#  1   Artist  2300 non-null   object
# dtypes: object(2)
# memory usage: 36.1+ KB

# %%
#Save the DataFrame

not_hot_song.to_csv('not_hot_song.csv', index=False)
